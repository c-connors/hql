# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker
from IPython.display import Image
from IPython.display import display
import os.path

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams.update({'font.size': 12})

def csv_read(file_name):
    return genfromtxt(file_name, delimiter=' ')

def load_stat(data, max_size):
    data_valid = []
    for x in data:
        if os.path.isfile(x + '.csv'):
            data_valid.append(x)
        else:
            print(x + '.csv is not found.')
    
    stat = np.zeros((len(data_valid), max_size, 4))
    idx = 0
    for x in data_valid:
        log = csv_read(x + '.csv')
        #opt = csv_read(opt_path)
        for i in range(0, max_size):
            stat[idx][i][0] = log[i][1]
            stat[idx][i][1] = log[i][2]
            stat[idx][i][2] = log[i][3]
            stat[idx][i][3] = log[i][4] # - opt[i][4]
        idx = idx + 1
    return stat.mean(0), stat.std(0) / np.sqrt(len(data_valid))

def plot_curve(ax, mean, std, color, label, linestyle, marker, step=1):
    ax.fill_between(range(1, mean.size+1, step), mean[0:mean.size:step]-std[0:mean.size:step], 
                    mean[0:mean.size:step]+std[0:mean.size:step], 
                    facecolor=color, interpolate=True, alpha=0.15, edgecolor='lightgrey', linewidth=0.5)
    
    ax.plot(range(1, mean.size+1, step), mean[0:mean.size:step], 
                    color=color, label=label, marker=marker, linestyle=linestyle, markersize=4, alpha=1, linewidth=2.5)
    
def format_plot(ax, fig, max_size):
    ax.set_xlabel('Num of instructions', fontsize=12)
    ax.relim()
    ax.autoscale_view()
    ax.set_xlim(0, max_size)
    ax.grid(which='both', alpha=0.6)
    ax.grid(which='both', alpha=0.6)
    # ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
    # handles, labels = ax.get_legend_handles_labels()
    # ax.legend(handles, labels, loc=4, prop={'size':12}, labelspacing=0.1, borderpad=0.1)
    fig.tight_layout()
        
def plot_error(figs, axes, data, max_size, color, label, linestyle, marker):
    mean, std = load_stat(data, max_size)
    idx = 0
    for ax in axes:
        plot_curve(ax, mean[:,idx], std[:,idx], color, label, linestyle, marker)
        format_plot(ax, figs[idx], max_size)
        idx = idx + 1
    
    print(label, '%.2f (%.2f)' % (mean[max_size-1, 0], std[max_size-1, 0]), 
                 '%.1f%% (%.2f)' % (mean[max_size-1, 1] * 100, std[max_size-1, 1] * 100))

def create_plot():    
    fig, ax = plt.subplots(1)
    fig.set_size_inches(3, 3)
    return fig, ax

color = []
# color.append('gray')
color.append('royalblue')
color.append('limegreen')
color.append('coral')
color.append('gold')
color.append('lightpink')

# %%
max_size = 10
fig1, ax1 = create_plot()
fig2, ax2 = create_plot()
fig3, ax3 = create_plot()
fig4, ax4 = create_plot()
#opt_path = 'no_penalty/opt_all_seen.csv'

ta_seen = ['csv/ta_seen.csv']
ta_unseen = []
nta_seen = []
nta_unseen = []
ta_nreg_seen = []
ta_nreg_unseen = []
nta_nreg_seen = []
nta_nreg_unseen = []
flat_seen = ['csv/flat_seen.csv']
flat_unseen = []

    
#plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["no_penalty/opt_all_seen"], max_size, "darkgray", "Near-Optimal", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], flat_seen, max_size, color[3], "Flat (Seen)", "-", "")
#plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], flat_unseen, max_size, color[3], "Flat (Unseen)", "--", "")
#plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], nta_seen, max_size, color[1], "Ours w/o TA (Seen)", "-", "")
#plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], nta_unseen, max_size, color[1], "Ours w/o TA (Unseen)", "--", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ta_seen, max_size, color[0], "Ours w/ TA (Seen)", "-", "")
#plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ta_unseen, max_size, color[0], "Ours w/ TA (Unseen)", "--", "")


ax1.set_ylabel('Reward', fontsize=12)
ax2.set_ylabel('Success rate', fontsize=12)
ax3.set_ylabel('#instructions completed', fontsize=12)
ax4.set_ylabel('#steps', fontsize=12)

ax1.set_xlim(1, max_size)
ax2.set_xlim(1, max_size)
ax3.set_xlim(1, max_size)
ax4.set_xlim(1, max_size)
#ax2.set_ylim(0.8, 1)

#handles, labels = ax1.get_legend_handles_labels()
#ax1.legend(handles, labels, loc=4, prop={'size':10}, labelspacing=0.1, borderpad=0.1)
figLegend = plt.figure(figsize = (3,0.7))
plt.figlegend(*ax1.get_legend_handles_labels(), loc = 'upper left')

figLegend.savefig('plot/3d_legend.png', bbox_inches='tight')
figLegend.savefig('plot/3d_legend.pdf', bbox_inches='tight')

fig1.savefig('plot/3d_reward.png', bbox_inches='tight')
fig1.savefig('plot/3d_reward.pdf', bbox_inches='tight')
fig2.savefig('plot/3d_success.png', bbox_inches='tight')
fig2.savefig('plot/3d_success.pdf', bbox_inches='tight')
fig3.savefig('plot/3d_instructions.png', bbox_inches='tight')
fig3.savefig('plot/3d_instructions.pdf', bbox_inches='tight')
fig4.savefig('plot/3d_step.png', bbox_inches='tight')
fig4.savefig('plot/3d_step.pdf', bbox_inches='tight')

plt.close()
# Out:
# ('Near-Optimal', '-10.31 (0.00)', '99.3% (0.00)')
# ('Flat (Seen)', '-18.83 (0.05)', '0.1% (0.05)')
# ('Flat (Unseen)', '-18.92 (0.07)', '0.0% (0.00)')
# ('Ours w/o TA (Seen)', '-15.52 (0.70)', '32.2% (8.26)')
# ('Ours w/o TA (Unseen)', '-17.08 (0.30)', '12.9% (3.35)')
# ('Ours w/ TA (Seen)', '-11.30 (0.25)', '81.3% (3.00)')
# ('Ours w/ TA (Unseen)', '-14.75 (0.32)', '40.3% (3.84)')

# %%
a = Image(filename='plot/3d_legend.png') 
b = Image(filename='plot/3d_reward.png') 
c = Image(filename='plot/3d_success.png') 
d = Image(filename='plot/3d_instructions.png') 
e = Image(filename='plot/3d_step.png') 
display(a, b, c, d, e)

# %%
max_size = 20
fig1, ax1 = create_plot()
fig2, ax2 = create_plot()
fig3, ax3 = create_plot()
fig4, ax4 = create_plot()
opt_path = 'vphchr_result/opt.csv'

ta_seen = []
ta_unseen = []
nta_seen = []
nta_unseen = []
nam_seen = []
nam_unseen = []
#for i in range(0, 20):
#    ta_seen.append("final/" + (i+1) + )
    
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["vphchr_result/opt"], max_size, "darkgray", "Shortest-Hueristic", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/nta_nreg_hard_seen", 
                                                            "final/2/nta_nreg_hard_seen",
                                                            "final/3/nta_nreg_hard_seen",
                                                            "final/4/nta_nreg_hard_seen",
                                                            "final/5/nta_nreg_hard_seen",
                                                            "final/6/nta_nreg_hard_seen",
                                                            "final/7/nta_nreg_hard_seen",
                                                            "final/8/nta_nreg_hard_seen",
                                                            "final/9/nta_nreg_hard_seen",
                                                            "final/10/nta_nreg_hard_seen",
                                                            "final/11/nta_nreg_hard_seen", 
                                                            "final/12/nta_nreg_hard_seen",
                                                            "final/13/nta_nreg_hard_seen",
                                                            "final/14/nta_nreg_hard_seen",
                                                            "final/15/nta_nreg_hard_seen",
                                                            "final/16/nta_nreg_hard_seen",
                                                            "final/17/nta_nreg_hard_seen",
                                                            "final/18/nta_nreg_hard_seen",
                                                            "final/19/nta_nreg_hard_seen",
                                                            "final/20/nta_nreg_hard_seen",
                                                            "final/21/nta_nreg_hard_seen",
                                                            "final/22/nta_nreg_hard_seen",
                                                            "final/23/nta_nreg_hard_seen",
                                                            "final/24/nta_nreg_hard_seen",
                                                           ], max_size, color[3], "Hard (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/nta_nreg_hard_unseen", 
                                                            "final/2/nta_nreg_hard_unseen",
                                                            "final/3/nta_nreg_hard_unseen",
                                                            "final/4/nta_nreg_hard_unseen",
                                                            "final/5/nta_nreg_hard_unseen",
                                                            "final/6/nta_nreg_hard_unseen",
                                                            "final/7/nta_nreg_hard_unseen",
                                                            "final/8/nta_nreg_hard_unseen",
                                                            "final/9/nta_nreg_hard_unseen",
                                                            "final/10/nta_nreg_hard_unseen",
                                                            "final/11/nta_nreg_hard_unseen", 
                                                            "final/12/nta_nreg_hard_unseen",
                                                            "final/13/nta_nreg_hard_unseen",
                                                            "final/14/nta_nreg_hard_unseen",
                                                            "final/15/nta_nreg_hard_unseen",
                                                            "final/16/nta_nreg_hard_unseen",
                                                            "final/17/nta_nreg_hard_unseen",
                                                            "final/18/nta_nreg_hard_unseen",
                                                            "final/19/nta_nreg_hard_unseen",
                                                            "final/20/nta_nreg_hard_unseen",
                                                            "final/21/nta_nreg_hard_unseen",
                                                            "final/22/nta_nreg_hard_unseen",
                                                            "final/23/nta_nreg_hard_unseen",
                                                            "final/24/nta_nreg_hard_unseen",
                                                           ], max_size, color[3], "Hard (Unseen)", "--", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/nta_hard_seen", 
                                                            "final/2/nta_hard_seen",
                                                            "final/3/nta_hard_seen",
                                                            "final/4/nta_hard_seen",
                                                            "final/5/nta_hard_seen",
                                                            "final/6/nta_hard_seen",
                                                            "final/7/nta_hard_seen",
                                                            "final/8/nta_hard_seen",
                                                            "final/9/nta_hard_seen",
                                                            "final/10/nta_hard_seen",
                                                            "final/11/nta_hard_seen", 
                                                            "final/12/nta_hard_seen",
                                                            "final/13/nta_hard_seen",
                                                            "final/14/nta_hard_seen",
                                                            "final/15/nta_hard_seen",
                                                            "final/16/nta_hard_seen",
                                                            "final/17/nta_hard_seen",
                                                            "final/18/nta_hard_seen",
                                                            "final/19/nta_hard_seen",
                                                            "final/20/nta_hard_seen",
                                                            "final/21/nta_hard_seen",
                                                            "final/22/nta_hard_seen",
                                                            "final/23/nta_hard_seen",
                                                            "final/24/nta_hard_seen",
                                                           ], max_size, color[1], "Analogy-Hard (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/nta_hard_unseen", 
                                                            "final/2/nta_hard_unseen",
                                                            "final/3/nta_hard_unseen",
                                                            "final/4/nta_hard_unseen",
                                                            "final/5/nta_hard_unseen",
                                                            "final/6/nta_hard_unseen",
                                                            "final/7/nta_hard_unseen",
                                                            "final/8/nta_hard_unseen",
                                                            "final/9/nta_hard_unseen",
                                                            "final/10/nta_hard_unseen",
                                                            "final/11/nta_hard_unseen", 
                                                            "final/12/nta_hard_unseen",
                                                            "final/13/nta_hard_unseen",
                                                            "final/14/nta_hard_unseen",
                                                            "final/15/nta_hard_unseen",
                                                            "final/16/nta_hard_unseen",
                                                            "final/17/nta_hard_unseen",
                                                            "final/18/nta_hard_unseen",
                                                            "final/19/nta_hard_unseen",
                                                            "final/20/nta_hard_unseen",
                                                            "final/21/nta_hard_unseen",
                                                            "final/22/nta_hard_unseen",
                                                            "final/23/nta_hard_unseen",
                                                            "final/24/nta_hard_unseen",
                                                           ], max_size, color[1], "Analogy-Hard (Unseen)", "--", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_nreg_hard_seen",
                                                            "final/2/ta_nreg_hard_seen",
                                                            "final/3/ta_nreg_hard_seen",
                                                            "final/4/ta_nreg_hard_seen",
                                                            "final/5/ta_nreg_hard_seen",
                                                            "final/6/ta_nreg_hard_seen",
                                                            "final/7/ta_nreg_hard_seen",
                                                            "final/8/ta_nreg_hard_seen",
                                                            "final/9/ta_nreg_hard_seen",
                                                            "final/10/ta_nreg_hard_seen",
                                                            "final/11/ta_nreg_hard_seen",
                                                            "final/12/ta_nreg_hard_seen",
                                                            "final/13/ta_nreg_hard_seen",
                                                            "final/14/ta_nreg_hard_seen",
                                                            "final/15/ta_nreg_hard_seen",
                                                            "final/16/ta_nreg_hard_seen",
                                                            "final/17/ta_nreg_hard_seen",
                                                            "final/18/ta_nreg_hard_seen",
                                                            "final/19/ta_nreg_hard_seen",
                                                            "final/20/ta_nreg_hard_seen",
                                                            "final/21/ta_nreg_hard_seen",
                                                            "final/22/ta_nreg_hard_seen",
                                                            "final/23/ta_nreg_hard_seen",
                                                            "final/24/ta_nreg_hard_seen",
                                                           ], max_size, color[2], "TA-Hard (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_nreg_hard_unseen",
                                                            "final/2/ta_nreg_hard_unseen",
                                                            "final/3/ta_nreg_hard_unseen",
                                                            "final/4/ta_nreg_hard_unseen",
                                                            "final/5/ta_nreg_hard_unseen",
                                                            "final/6/ta_nreg_hard_unseen",
                                                            "final/7/ta_nreg_hard_unseen",
                                                            "final/8/ta_nreg_hard_unseen",
                                                            "final/9/ta_nreg_hard_unseen",
                                                            "final/10/ta_nreg_hard_unseen",
                                                            "final/11/ta_nreg_hard_unseen",
                                                            "final/12/ta_nreg_hard_unseen",
                                                            "final/13/ta_nreg_hard_unseen",
                                                            "final/14/ta_nreg_hard_unseen",
                                                            "final/15/ta_nreg_hard_unseen",
                                                            "final/16/ta_nreg_hard_unseen",
                                                            "final/17/ta_nreg_hard_unseen",
                                                            "final/18/ta_nreg_hard_unseen",
                                                            "final/19/ta_nreg_hard_unseen",
                                                            "final/20/ta_nreg_hard_unseen",
                                                            "final/21/ta_nreg_hard_unseen",
                                                            "final/22/ta_nreg_hard_unseen",
                                                            "final/23/ta_nreg_hard_unseen",
                                                            "final/24/ta_nreg_hard_unseen",
                                                           ], max_size, color[2], "TA-Hard (Unseen)", "--", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_hard_seen", 
                                                            "final/2/ta_hard_seen",
                                                            "final/3/ta_hard_seen",
                                                            "final/4/ta_hard_seen",
                                                            "final/5/ta_hard_seen",
                                                            "final/6/ta_hard_seen",
                                                            "final/7/ta_hard_seen",
                                                            "final/8/ta_hard_seen",
                                                            "final/9/ta_hard_seen",
                                                            "final/10/ta_hard_seen",
                                                            "final/11/ta_hard_seen", 
                                                            #"final/12/ta_hard_seen",
                                                            "final/13/ta_hard_seen",
                                                            "final/14/ta_hard_seen",
                                                            "final/15/ta_hard_seen",
                                                            "final/16/ta_hard_seen",
                                                            "final/17/ta_hard_seen",
                                                            "final/18/ta_hard_seen",
                                                            "final/19/ta_hard_seen",
                                                            "final/20/ta_hard_seen",
                                                            "final/21/ta_hard_seen",
                                                            "final/22/ta_hard_seen",
                                                            "final/23/ta_hard_seen",
                                                            "final/24/ta_hard_seen",
                                                           ], max_size, color[0], "TA-Analogy-Hard (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_hard_unseen", 
                                                            "final/2/ta_hard_unseen",
                                                            "final/3/ta_hard_unseen",
                                                            "final/4/ta_hard_unseen",
                                                            "final/5/ta_hard_unseen",
                                                            "final/6/ta_hard_unseen",
                                                            "final/7/ta_hard_unseen",
                                                            "final/8/ta_hard_unseen",
                                                            "final/9/ta_hard_unseen",
                                                            "final/10/ta_hard_unseen",
                                                            "final/11/ta_hard_unseen", 
                                                            #"final/12/ta_hard_unseen",
                                                            "final/13/ta_hard_unseen",
                                                            "final/14/ta_hard_unseen",
                                                            "final/15/ta_hard_unseen",
                                                            "final/16/ta_hard_unseen",
                                                            "final/17/ta_hard_unseen",
                                                            "final/18/ta_hard_unseen",
                                                            "final/19/ta_hard_unseen",
                                                            "final/20/ta_hard_unseen",
                                                            "final/21/ta_hard_unseen",
                                                            "final/22/ta_hard_unseen",
                                                            "final/23/ta_hard_unseen",
                                                            "final/24/ta_hard_unseen",
                                                           ], max_size, color[0], "TA-Analogy-Hard (Unseen)", "--", "")

ax1.set_ylabel('Reward', fontsize=12)
ax2.set_ylabel('Success rate', fontsize=12)
ax3.set_ylabel('#instructions completed', fontsize=12)
ax4.set_ylabel('#steps', fontsize=12)

ax1.set_xlim(1, max_size)
ax2.set_xlim(1, max_size)
ax3.set_xlim(1, max_size)
ax4.set_xlim(1, max_size)
#ax2.set_ylim(0.8, 1)

#handles, labels = ax1.get_legend_handles_labels()
#ax1.legend(handles, labels, loc=4, prop={'size':10}, labelspacing=0.1, borderpad=0.1)
figLegend = plt.figure(figsize = (3,0.7))
plt.figlegend(*ax1.get_legend_handles_labels(), loc = 'upper left')
figLegend.savefig('result/vphchr_legend.png', bbox_inches='tight')
figLegend.savefig('result/vphchr_legend.pdf', bbox_inches='tight')


fig1.savefig('result/vphchr_reward.png', bbox_inches='tight')
fig1.savefig('result/vphchr_reward.pdf', bbox_inches='tight')
fig2.savefig('result/vphchr_success.png', bbox_inches='tight')
fig2.savefig('result/vphchr_success.pdf', bbox_inches='tight')
fig3.savefig('result/vphchr_instructions.png', bbox_inches='tight')
fig3.savefig('result/vphchr_instructions.pdf', bbox_inches='tight')
fig4.savefig('result/vphchr_step.png', bbox_inches='tight')
fig4.savefig('result/vphchr_step.pdf', bbox_inches='tight')

plt.close()
# Out:
# ('Shortest-Hueristic', '-9.99 (0.00)', '99.1% (0.00)')
# final/1/nta_nreg_hard_seen.csv is not found.
# ('Hard (Seen)', '-16.86 (0.38)', '10.8% (4.79)')
# final/1/nta_nreg_hard_unseen.csv is not found.
# ('Hard (Unseen)', '-17.46 (0.10)', '3.0% (1.56)')
# ('Analogy-Hard (Seen)', '-14.82 (0.63)', '38.6% (8.23)')
# ('Analogy-Hard (Unseen)', '-16.22 (0.47)', '19.4% (5.67)')
# ('TA-Hard (Seen)', '-13.64 (0.68)', '52.3% (8.60)')
# ('TA-Hard (Unseen)', '-17.21 (0.15)', '8.3% (2.33)')
# ('TA-Analogy-Hard (Seen)', '-11.82 (0.50)', '76.8% (6.24)')
# ('TA-Analogy-Hard (Unseen)', '-15.25 (0.34)', '33.2% (3.87)')

# %%
a = Image(filename='result/vphchr_legend.png') 
b = Image(filename='result/vphchr_reward.png') 
c = Image(filename='result/vphchr_success.png') 
d = Image(filename='result/vphchr_instructions.png') 
e = Image(filename='result/vphchr_step.png') 
display(a, b, c, d, e)

# %%
max_size = 20
fig1, ax1 = create_plot()
fig2, ax2 = create_plot()
fig3, ax3 = create_plot()
fig4, ax4 = create_plot()
opt_path = 'vphchr_result/opt.csv'
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["vphchr_result/opt"], max_size, "black", "Hueristic", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_soft_seen", 
                                                            "final/2/ta_soft_seen",
                                                            "final/3/ta_soft_seen",
                                                            "final/4/ta_soft_seen",
                                                            "final/5/ta_soft_seen",
                                                            "final/6/ta_soft_seen",
                                                            "final/7/ta_soft_seen",
                                                            "final/8/ta_soft_seen",
                                                            "final/9/ta_soft_seen",
                                                            "final/10/ta_soft_seen",
                                                            "final/11/ta_soft_seen", 
                                                            "final/12/ta_soft_seen",
                                                            "final/13/ta_soft_seen",
                                                            "final/14/ta_soft_seen",
                                                            "final/15/ta_soft_seen",
                                                            "final/16/ta_soft_seen",
                                                            "final/17/ta_soft_seen",
                                                            "final/18/ta_soft_seen",
                                                            "final/19/ta_soft_seen",
                                                            "final/20/ta_soft_seen",
                                                            "r1/ta_soft_seen",
                                                            "r2/ta_soft_seen",
                                                            "r3/ta_soft_seen",
                                                            "r4/ta_soft_seen",
                                                           ], max_size, color[0], "TA+AM (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_soft_unseen", 
                                                            "final/2/ta_soft_unseen",
                                                            "final/3/ta_soft_unseen",
                                                            "final/4/ta_soft_unseen",
                                                            "final/5/ta_soft_unseen",
                                                            "final/6/ta_soft_unseen",
                                                            "final/7/ta_soft_unseen",
                                                            "final/8/ta_soft_unseen",
                                                            "final/9/ta_soft_unseen",
                                                            "final/10/ta_soft_unseen",
                                                            "final/11/ta_soft_unseen", 
                                                            "final/12/ta_soft_unseen",
                                                            "final/13/ta_soft_unseen",
                                                            "final/14/ta_soft_unseen",
                                                            "final/15/ta_soft_unseen",
                                                            "final/16/ta_soft_unseen",
                                                            "final/17/ta_soft_unseen",
                                                            "final/18/ta_soft_unseen",
                                                            "final/19/ta_soft_unseen",
                                                            "final/20/ta_soft_unseen",
                                                            "r1/ta_soft_unseen",
                                                            "r2/ta_soft_unseen",
                                                            "r3/ta_soft_unseen",
                                                            "r4/ta_soft_unseen",
                                                           ], max_size, color[0], "TA+AM (Unseen)", "--", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/nta_soft_seen", 
                                                            "final/2/nta_soft_seen",
                                                            "final/3/nta_soft_seen",
                                                            "final/4/nta_soft_seen",
                                                            "final/5/nta_soft_seen",
                                                            "final/6/nta_soft_seen",
                                                            "final/7/nta_soft_seen",
                                                            "final/8/nta_soft_seen",
                                                            "final/9/nta_soft_seen",
                                                            "final/10/nta_soft_seen",
                                                            "final/11/nta_soft_seen", 
                                                            "final/12/nta_soft_seen",
                                                            "final/13/nta_soft_seen",
                                                            "final/14/nta_soft_seen",
                                                            "final/15/nta_soft_seen",
                                                            "final/16/nta_soft_seen",
                                                            "final/17/nta_soft_seen",
                                                            "final/18/nta_soft_seen",
                                                            "final/19/nta_soft_seen",
                                                            "final/20/nta_soft_seen",
                                                            "r1/nta_soft_seen",
                                                            "r2/nta_soft_seen",
                                                            "r3/nta_soft_seen",
                                                            "r4/nta_soft_seen",
                                                           ], max_size, color[1], "AM (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/nta_soft_unseen", 
                                                            "final/2/nta_soft_unseen",
                                                            "final/3/nta_soft_unseen",
                                                            "final/4/nta_soft_unseen",
                                                            "final/5/nta_soft_unseen",
                                                            "final/6/nta_soft_unseen",
                                                            "final/7/nta_soft_unseen",
                                                            "final/8/nta_soft_unseen",
                                                            "final/9/nta_soft_unseen",
                                                            "final/10/nta_soft_unseen",
                                                            "final/11/nta_soft_unseen", 
                                                            "final/12/nta_soft_unseen",
                                                            "final/13/nta_soft_unseen",
                                                            "final/14/nta_soft_unseen",
                                                            "final/15/nta_soft_unseen",
                                                            "final/16/nta_soft_unseen",
                                                            "final/17/nta_soft_unseen",
                                                            "final/18/nta_soft_unseen",
                                                            "final/19/nta_soft_unseen",
                                                            "final/20/nta_soft_unseen",
                                                            "r1/nta_soft_unseen",
                                                            "r2/nta_soft_unseen",
                                                            "r3/nta_soft_unseen",
                                                            "r4/nta_soft_unseen",
                                                           ], max_size, color[1], "AM (Unseen)", "--", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_nreg_soft_seen",
                                                            "final/2/ta_nreg_soft_seen",
                                                            "final/3/ta_nreg_soft_seen",
                                                            "final/4/ta_nreg_soft_seen",
                                                            "final/5/ta_nreg_soft_seen",
                                                            "final/6/ta_nreg_soft_seen",
                                                            "final/7/ta_nreg_soft_seen",
                                                            "final/8/ta_nreg_soft_seen",
                                                            "final/9/ta_nreg_soft_seen",
                                                            "final/10/ta_nreg_soft_seen",
                                                            "final/11/ta_nreg_soft_seen",
                                                            "final/12/ta_nreg_soft_seen",
                                                            "final/13/ta_nreg_soft_seen",
                                                            "final/14/ta_nreg_soft_seen",
                                                            "final/15/ta_nreg_soft_seen",
                                                            "final/16/ta_nreg_soft_seen",
                                                            "final/17/ta_nreg_soft_seen",
                                                            "final/18/ta_nreg_soft_seen",
                                                            "final/19/ta_nreg_soft_seen",
                                                            "final/20/ta_nreg_soft_seen",
                                                            "r1/ta_nreg_soft_seen",
                                                            "r2/ta_nreg_soft_seen",
                                                            "r3/ta_nreg_soft_seen",
                                                            "r4/ta_nreg_soft_seen",
                                                           ], max_size, color[2], "TA (Seen)", "-", "")
plot_error([fig1, fig2, fig3, fig4], [ax1, ax2, ax3, ax4], ["final/1/ta_nreg_soft_unseen",
                                                            "final/2/ta_nreg_soft_unseen",
                                                            "final/3/ta_nreg_soft_unseen",
                                                            "final/4/ta_nreg_soft_unseen",
                                                            "final/5/ta_nreg_soft_unseen",
                                                            "final/6/ta_nreg_soft_unseen",
                                                            "final/7/ta_nreg_soft_unseen",
                                                            "final/8/ta_nreg_soft_unseen",
                                                            "final/9/ta_nreg_soft_unseen",
                                                            "final/10/ta_nreg_soft_unseen",
                                                            "final/11/ta_nreg_soft_unseen",
                                                            "final/12/ta_nreg_soft_unseen",
                                                            "final/13/ta_nreg_soft_unseen",
                                                            "final/14/ta_nreg_soft_unseen",
                                                            "final/15/ta_nreg_soft_unseen",
                                                            "final/16/ta_nreg_soft_unseen",
                                                            "final/17/ta_nreg_soft_unseen",
                                                            "final/18/ta_nreg_soft_unseen",
                                                            "final/19/ta_nreg_soft_unseen",
                                                            "final/20/ta_nreg_soft_unseen",
                                                            "r1/ta_nreg_soft_unseen",
                                                            "r2/ta_nreg_soft_unseen",
                                                            "r3/ta_nreg_soft_unseen",
                                                            "r4/ta_nreg_soft_unseen",
                                                           ], max_size, color[2], "TA (Unseen)", "--", "")

ax1.set_ylabel('Reward', fontsize=12)
ax2.set_ylabel('Success rate', fontsize=12)
ax3.set_ylabel('#instructions completed', fontsize=12)
ax4.set_ylabel('Extra steps', fontsize=12)

ax1.set_xlim(1, max_size)
ax2.set_xlim(1, max_size)
ax3.set_xlim(1, max_size)
ax4.set_xlim(1, max_size)
#ax2.set_ylim(0.8, 1)

#handles, labels = ax1.get_legend_handles_labels()
#ax1.legend(handles, labels, loc=4, prop={'size':10}, labelspacing=0.1, borderpad=0.1)
figLegend = plt.figure(figsize = (4,1.5))
plt.figlegend(*ax1.get_legend_handles_labels(), loc = 'upper left')
figLegend.savefig('result/vphchr_soft_legend.png', bbox_inches='tight')
figLegend.savefig('result/vphchr_soft_legend.pdf', bbox_inches='tight')


fig1.savefig('result/vphchr_soft_reward.png', bbox_inches='tight')
fig1.savefig('result/vphchr_soft_reward.pdf', bbox_inches='tight')
fig2.savefig('result/vphchr_soft_success.png', bbox_inches='tight')
fig2.savefig('result/vphchr_soft_success.pdf', bbox_inches='tight')
fig3.savefig('result/vphchr_soft_instructions.png', bbox_inches='tight')
fig3.savefig('result/vphchr_soft_instructions.pdf', bbox_inches='tight')
fig4.savefig('result/vphchr_soft_step.png', bbox_inches='tight')
fig4.savefig('result/vphchr_soft_step.pdf', bbox_inches='tight')

plt.close()
# Out:
# ('Hueristic', '-9.99 (0.00)', '99.1% (0.00)')
# final/5/ta_soft_seen.csv is not found.
# final/15/ta_soft_seen.csv is not found.
# final/18/ta_soft_seen.csv is not found.
# final/19/ta_soft_seen.csv is not found.
# final/20/ta_soft_seen.csv is not found.
# ('TA+AM (Seen)', '-11.79 (0.54)', '76.6% (5.73)')
# final/15/ta_soft_unseen.csv is not found.
# final/18/ta_soft_unseen.csv is not found.
# final/19/ta_soft_unseen.csv is not found.
# final/20/ta_soft_unseen.csv is not found.
# ('TA+AM (Unseen)', '-16.61 (0.42)', '23.2% (4.01)')
# final/8/nta_soft_seen.csv is not found.
# final/14/nta_soft_seen.csv is not found.
# ('AM (Seen)', '-16.09 (0.72)', '29.9% (7.57)')
# final/8/nta_soft_unseen.csv is not found.
# final/14/nta_soft_unseen.csv is not found.
# ('AM (Unseen)', '-18.01 (0.31)', '8.2% (2.66)')
# final/15/ta_nreg_soft_seen.csv is not found.
# final/18/ta_nreg_soft_seen.csv is not found.
# ('TA (Seen)', '-15.92 (0.65)', '32.1% (6.67)')
# ...

# %%
a = Image(filename='result/vphchr_soft_legend.png') 
b = Image(filename='result/vphchr_soft_reward.png') 
c = Image(filename='result/vphchr_soft_success.png') 
d = Image(filename='result/vphchr_soft_instructions.png') 
e = Image(filename='result/vphchr_soft_step.png') 
display(a, b, c, d, e)
